# %% [markdown]
# ## Twitter API Challenge (Search)
#
# > If you have not had a chance to check out the [Lazy Guide to Web Scraping](https://github.com/sportsdatasolutions/sport_x_code_eis/blob/master/3.projects/LazyGuides/web_scraping.md) please do so! You can find the code for the guide in this [Deepnote Project](https://deepnote.com/project/0d7f30b4-7eb4-4d7e-b601-28085e59e0d3#%2F1.OpenAPI.ipynb).
#
# #### In this challenge, you will simply be searching for recent tweets based on your `sport/team/personality` of choice.
#
# 1. ##### Firstly, if you dont have a Twitter account, you'll have to ***sign up*** for one.
# 2. ##### Once you are singed up, navigate to your [Developer Portal](https://developer.twitter.com/en/portal/dashboard)
# 3. ##### Create a new Project and App
# 4. ##### Copy the Bearer Token (this is sensitive, keep it safe, you can regenereate this token if you ever lose it)
# 5. ##### In your projects [Environment Variables](https://docs.deepnote.com/environment/environment-variables), add once called `BEARER_TOKEN` and paste in your Twitter App's Bearer Token as the value.
#
#     **Note**: Now we'll beable to access our 'sensitive' token without having to hard code it into our script, e.g.

# %%
import os

print(os.environ["BEARER_TOKEN"])

# %% [markdown]
# ### The Challenge
#
# > To get the data we want from Twitter, we'll be using their very own [Twitter API (V2)](https://developer.twitter.com/en/docs/twitter-api/early-access).
#
# 1. ##### Below is some sample code using the [`recent search`](https://developer.twitter.com/en/docs/twitter-api/tweets/search/introduction) endpoint. You can see the API reference for the `recent serch` endpoint [here](https://developer.twitter.com/en/docs/twitter-api/tweets/search/api-reference/get-tweets-search-recent) and a sample Python script [here](https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/master/Recent-Search/recent_search.py).
# 1. ##### Collate 1000 recent tweets on a sport/team/personality of your choice.
# 2. ##### Clean and Translate tweets (text) and perform a polarity assesment on all the tweets :)
# 3. ##### Optionally come up with a summary number/big ass number or even a visualisation of the polarity on your set of tweets about a specific sport/event/match.
#
#     **Hint**: This will help, simply ***note*** that we are ***not*** streaming in the data, simply requesting the last 1000 tweets: https://medium.com/@tomham000/world-cup-final-2018-twitter-analysis-in-python-2be24e116d59

# %%
## Dont be afraid to copy + past code, get it working, try understand it and refactor it if needed: https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/master/Recent-Search/recent_search.py

# %% [markdown]
# ## Twitter API Challenge (Stream)
#
# > If you have not had a chance to check out the [Lazy Guide to Web Scraping](https://github.com/sportsdatasolutions/sport_x_code_eis/blob/master/3.projects/LazyGuides/web_scraping.md) please do so! You can find the code for the guide in this [Deepnote Project](https://deepnote.com/project/0d7f30b4-7eb4-4d7e-b601-28085e59e0d3#%2F1.OpenAPI.ipynb).
#
# #### In this challenge, you will be streaming tweet during a live sports event/match of your choice, and conducting an analysis on the data.
#
# 1. ##### If you have not already, please read through this blog: https://medium.com/@tomham000/world-cup-final-2018-twitter-analysis-in-python-2be24e116d59
#
# 2. ##### Now pick a future event and set up your script to stream and collate all the tweet during that event. Note that the blog above is using a third-party lib called `tweepy`. You are not confined to using Twitter's API (although we would probably reccommend it for now).
#
# 3. ##### You can see the API reference for the `filtered stream` endpoint [here](https://developer.twitter.com/en/docs/twitter-api/tweets/filtered-stream/api-reference) and a sample Python script [here](https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/master/Filtered-Stream/filtered_stream.py).

# %%
## Dont be afraid to copy + past code, get it working, try understand it and refactor it if needed: https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/master/Filtered-Stream/filtered_stream.py
